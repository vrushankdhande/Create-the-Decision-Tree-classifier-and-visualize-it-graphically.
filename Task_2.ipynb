# %% [markdown]
# **Create the Decision Tree classifier and visualize it graphically.**
#
# **Task 2 -- THE SPARKS FOUNDATION**
#
# **Vrushank Dhande**
#
# ***Predict the percentage of an student based on the no. of study hours.***
#
# 1.   Used DecisionTreeClassifier to classifie the dataset
# 2.   Using Python
#
# 1.   Data link : https://bit.ly/3kXTdox
# 2.   The purpose is if we feed any new data to this classifier, it would be able to
# predict the right class accordingly.

# %% [markdown]
# 1. Used DecisionTreeClassifier to classify the dataset.
# 2. imported all the important libraries.

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import  DecisionTreeClassifier
from sklearn import tree
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %% [markdown]
# 1.  upload the data
# 2.  data is an overview

# %%
data_iris = pd.read_csv("/content/Iris (1).csv")
data_iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# 1.  The value of all the data and information of data
# 2.  The types present in the dataset

# %%
data_iris.info()
data_iris.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# ...

# %% [markdown]
# This are all the value for various species which are shown

# %%
data_iris["Species"].value_counts()
# Out:
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# Name: Species, dtype: int64

# %% [markdown]
# 1. Print the columns in the datasets
# 2. printing labels

# %%
data_iris.columns
print(data_iris.columns)
data_iris["Species"]=LabelEncoder().fit_transform(data_iris["Species"])
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# Here the dataset is divided in x and y
#
# where x = trageted column and y features column

# %%
x= data_iris.iloc[:,1:5]
Y=data_iris.iloc[:,5:]

# %% [markdown]
# **DATA IS SPLITED INTO TRAIN AND TEST**

# %%
x_train,x_test,Y_train,Y_test = train_test_split(x,Y,test_size=0.3,random_state=42)

# %% [markdown]
# 1.   **applied DecisionTree to the model**
# 2.   **the model is train**

# %%
model_iries = DecisionTreeClassifier()
model_iries.fit(x_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %% [markdown]
# 1.  the score of all the train dataset
# 2.  predication of the model test data
# 3.  testing the confusion matrix
# 4.  the score of test dataset

# %%
a=model_iries.score(x_train,Y_train)
prediction_model = model_iries.predict(x_test)
b=confusion_matrix(prediction,y_test)
c=model.score(X_test,y_test)
print(a)
print(prediction_model)
print(b)
print(c)
# Out:
# 1.0
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]
# 1.0

# %% [markdown]
# **The final diagram of decision tree by the model**

# %%
function=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
column=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(model,
               feature_names = function, 
               class_names=column,
               filled = True);
